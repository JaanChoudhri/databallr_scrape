# %% [markdown]
# #NBA Data Scraping Examples

# %% [markdown]
# ## Necessary Packages

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# [Stats Glossary](https://databallr.com/stats/glossary)

# %% [markdown]
# ## Data Retrieval

# %%
data_url = "https://api.databallr.com/api/supabase/player_stats_with_metrics?year=2026&playoffs=0&min_minutes=50&limit=500&order_by=dpm&order_direction=desc"
site_response = requests.get(data_url)

if site_response.status_code == 200:
    print(f"Successfully accessed the page: {data_url}")
else:
    print(f"Failed to retrieve page. Status code: {site_response.status_code}")    
    exit()

data=site_response.json()
print("\n")
print(f"Data type: {type(data)}")

allStats = pd.DataFrame(data)
display(allStats.head())
# Out:
# Successfully accessed the page: https://api.databallr.com/api/supabase/player_stats_with_metrics?year=2026&playoffs=0&min_minutes=50&limit=500&order_by=dpm&order_direction=desc
#
#
# Data type: <class 'list'>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>2PA_100</th><th>2PA_100_pos_pct</th><th>2P_PERC</th><th>2P_PERC_pos_pct</th><th>2TSA</th><th>2TSA_100</th><th>2TSA_100_pos_pct</th><th>2TSA_pos_pct</th><th>2TS_percent</th><th>2TS_percent_pos_pct</th><th>2rTS</th><th>2rTS_pos_pct</th><th>3PA_100</th><th>3PA_100_pos_pct</th><th>3PR</th><th>3PR_pos_pct</th><th>3P_PERC</th><th>3P_PERC_pos_pct</th><th>3TSA</th><th>3TSA_100</th><th>3TSA_100_pos_pct</th><th>3TSA_pos_pct</th><th>3TS_percent</th><th>3TS_percent_pos_pct</th><th>3rTS</th><th>3rTS_pos_pct</th><th>Age</th><th>AtRimAssists/100</th><th>AtRimAssists/100_pos_pct</th><th>Blocks_100</th><th>Blocks_100_pos_pct</th><th>Blocks_PG</th><th>Blocks_PG_pos_pct</th><th>DefFGReboundPct</th><th>DefFGReboundPct_pos_pct</th><th>DefPoss</th><th>FTA_100</th><th>FTA_100_pos_pct</th><th>FTOVS_PG</th><th>FTOVS_PG_pos_pct</th><th>FT_PERC</th><th>FT_PERC_pos_pct</th><th>GamesPlayed</th><th>LongMidFGPerc</th><th>LongMidFGPerc_pos_pct</th><th>MPG</th><th>MPG_pos_pct</th><th>Minutes</th><th>Name</th><th>OFFD_100</th><th>OFFD_100_pos_pct</th><th>OffFGReboundPct</th><th>OffFGReboundPct_pos_pct</th><th>OffPoss</th><th>Offensive Archetype</th><th>PASSING_AssistEFG</th><th>PASSING_AssistEFG_pos_pct</th><th>PASSING_BP%</th><th>PASSING_BP%_pos_pct</th><th>PASSING_DiscountedAssistEFG</th><th>PASSING_DiscountedAssistEFG_pos_pct</th><th>PASSING_POT_AST_PER_MIN</th><th>PASSING_POT_AST_PER_MIN_pos_pct</th><th>PASSING_Potential Assists/100</th><th>PASSING_Potential Assists/100_pos_pct</th><th>PASSING_on-ball-time%</th><th>PASSING_on-ball-time%_pos_pct</th><th>PlusMinus</th><th>Pos2</th><th>ProbabilityOffRebounded</th><th>ProbabilityOffRebounded_pos_pct</th><th>Pts75</th><th>Pts75_pos_pct</th><th>RimFGPerc</th><th>RimFGPerc_pos_pct</th><th>RowId</th><th>SFC_pct</th><th>SFC_pct_pos_pct</th><th>STOPS_100</th><th>STOPS_100_pos_pct</th><th>SecondsPlayed</th><th>SelfORebPct</th><th>SelfORebPct_pos_pct</th><th>ShortMidFGPerc</th><th>ShortMidFGPerc_pos_pct</th><th>ShortName</th><th>Steals_100</th><th>Steals_100_pos_pct</th><th>TSA100</th><th>TSA100_pos_pct</th><th>TS_added_100</th><th>TS_added_100_pos_pct</th><th>TS_pct</th><th>TS_pct_pos_pct</th><th>TeamAbbreviation</th><th>TeamId</th><th>TeammateMissORebPerc</th><th>TeammateMissORebPerc_pos_pct</th><th>adj_shot_quality</th><th>adj_shot_quality_pos_pct</th><th>block_recov_percent</th><th>block_recov_percent_pos_pct</th><th>box_ddpm</th><th>box_odpm</th><th>cTOV</th><th>cTOV_pos_pct</th><th>creation_TS</th><th>creation_TSA</th><th>creation_TSA_pos_pct</th><th>creation_TS_pos_pct</th><th>creation_rTS</th><th>creation_rTS_pos_pct</th><th>d_AssistPoints_Per100</th><th>d_AssistPoints_Per100_pos_pct</th><th>d_AssistPoints_PerGame</th><th>d_AssistPoints_PerGame_pos_pct</th><th>d_Assists_Per100</th><th>d_Assists_Per100_pos_pct</th><th>d_Assists_PerGame</th><th>d_Assists_PerGame_pos_pct</th><th>d_AtRimAssists_Per100</th><th>d_AtRimAssists_Per100_pos_pct</th><th>d_AtRimAssists_PerGame</th><th>d_AtRimAssists_PerGame_pos_pct</th><th>d_AtRimFGA_Per100</th><th>d_AtRimFGA_Per100_pos_pct</th><th>d_AtRimFGA_PerGame</th><th>d_AtRimFGA_PerGame_pos_pct</th><th>d_Blocks_Per100</th><th>d_Blocks_Per100_pos_pct</th><th>d_Blocks_PerGame</th><th>d_Blocks_PerGame_pos_pct</th><th>d_DEFLECTIONS_Per100</th><th>d_DEFLECTIONS_Per100_pos_pct</th><th>d_DEFLECTIONS_PerGame</th><th>d_DEFLECTIONS_PerGame_pos_pct</th><th>d_DEF_LOOSE_BALLS_RECOVERED_Per100</th><th>d_DEF_LOOSE_BALLS_RECOVERED_Per100_pos_pct</th><th>d_DEF_LOOSE_BALLS_RECOVERED_PerGame</th><th>d_DEF_LOOSE_BALLS_RECOVERED_PerGame_pos_pct</th><th>d_DefRebounds_Per100</th><th>d_DefRebounds_Per100_pos_pct</th><th>d_DefRebounds_PerGame</th><th>d_DefRebounds_PerGame_pos_pct</th><th>d_FG3A_Per100</th><th>d_FG3A_Per100_pos_pct</th><th>d_FG3A_PerGame</th><th>d_FG3A_PerGame_pos_pct</th><th>d_FTA_Per100</th><th>d_FTA_Per100_pos_pct</th><th>d_FTA_PerGame</th><th>d_FTA_PerGame_pos_pct</th>< ...

# %% [markdown]
# ##Offense

# %% [markdown]
# ### Basic Metrics

# %%
basicOffCols = ['Name', 'Pos2','Offensive Archetype', 'TeamAbbreviation',  'GamesPlayed', 'MPG', 'd_Points_PerGame', '3P_PERC', 'd_FG3A_PerGame', 'FT_PERC', 'd_Rebounds_PerGame', 'd_Assists_PerGame']
basicOffStats = allStats[basicOffCols][allStats['MPG']>15]  # filter out noise, role players
display(basicOffStats.head())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Name</th><th>Pos2</th><th>Offensive Archetype</th><th>TeamAbbreviation</th><th>GamesPlayed</th><th>MPG</th><th>d_Points_PerGame</th><th>3P_PERC</th><th>d_FG3A_PerGame</th><th>FT_PERC</th><th>d_Rebounds_PerGame</th><th>d_Assists_PerGame</th></tr></thead><tbody><tr><td>Nikola Jokić</td><td>C</td><td>Post Scorer</td><td>DEN</td><td>42</td><td>34.262</td><td>28.762</td><td>0.421</td><td>4.643</td><td>0.836</td><td>12.524</td><td>10.524</td></tr><tr><td>Shai Gilgeous-Alexander</td><td>PG</td><td>Shot Creator</td><td>OKC</td><td>49</td><td>33.306</td><td>31.796</td><td>0.39</td><td>4.551</td><td>0.892</td><td>4.449</td><td>6.408</td></tr><tr><td>Kawhi Leonard</td><td>SF</td><td>Shot Creator</td><td>LAC</td><td>44</td><td>32.75</td><td>28.045</td><td>0.381</td><td>6.977</td><td>0.905</td><td>6.364</td><td>3.705</td></tr><tr><td>Giannis Antetokounmpo</td><td>PF</td><td>Shot Creator</td><td>MIL</td><td>30</td><td>29.2</td><td>27.967</td><td>0.395</td><td>1.267</td><td>0.658</td><td>10.033</td><td>5.6</td></tr><tr><td>Donovan Mitchell</td><td>PG</td><td>Primary Ball Handler</td><td>CLE</td><td>55</td><td>33.455</td><td>28.545</td><td>0.369</td><td>9.4</td><td>0.852</td><td>4.491</td><td>5.818</td></tr></tbody></table></div>

# %% [markdown]
# Nice! We successfully returned our data. However, it looks a bit messy. Percentages aren't clean and there are too many decimals. Let's work towards cleaning up the data so it looks nice.

# %%
basicOffStats = basicOffStats.rename( #Rename Columns to look like standard stat s
                    columns = {'TeamAbbreviation': 'Team',
                               'Pos2': 'Pos',
                               'd_Points_PerGame': 'PPG',
                               '3P_PERC': '_3P_Pct',
                               'd_FG3A_PerGame': '_3PA',
                               'FT_PERC': 'FT_Pct',
                               'd_Rebounds_PerGame' :'RPG',
                               'd_Assists_PerGame': 'APG',
}
                    )


basicOffStats = basicOffStats.assign(
    MPG = (basicOffStats['MPG']).round(1),
    PPG = (basicOffStats['PPG']).round(1),
    RPG = (basicOffStats['RPG']).round(1),
    APG = (basicOffStats['APG']).round(1),
    _3PA = (basicOffStats['_3PA']).round(1),
    FT_Pct = (basicOffStats['FT_Pct'] * 100).round(1).astype(str) + '%',
    _3P_Pct = (basicOffStats['_3P_Pct'] * 100).round(1).astype(str) + '%'    
)

display(basicOffStats.head())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Name</th><th>Pos</th><th>Offensive Archetype</th><th>Team</th><th>GamesPlayed</th><th>MPG</th><th>PPG</th><th>_3P_Pct</th><th>_3PA</th><th>FT_Pct</th><th>RPG</th><th>APG</th></tr></thead><tbody><tr><td>Nikola Jokić</td><td>C</td><td>Post Scorer</td><td>DEN</td><td>42</td><td>34.3</td><td>28.8</td><td>42.1%</td><td>4.6</td><td>83.6%</td><td>12.5</td><td>10.5</td></tr><tr><td>Shai Gilgeous-Alexander</td><td>PG</td><td>Shot Creator</td><td>OKC</td><td>49</td><td>33.3</td><td>31.8</td><td>39.0%</td><td>4.6</td><td>89.2%</td><td>4.4</td><td>6.4</td></tr><tr><td>Kawhi Leonard</td><td>SF</td><td>Shot Creator</td><td>LAC</td><td>44</td><td>32.8</td><td>28.0</td><td>38.1%</td><td>7.0</td><td>90.5%</td><td>6.4</td><td>3.7</td></tr><tr><td>Giannis Antetokounmpo</td><td>PF</td><td>Shot Creator</td><td>MIL</td><td>30</td><td>29.2</td><td>28.0</td><td>39.5%</td><td>1.3</td><td>65.8%</td><td>10.0</td><td>5.6</td></tr><tr><td>Donovan Mitchell</td><td>PG</td><td>Primary Ball Handler</td><td>CLE</td><td>55</td><td>33.5</td><td>28.5</td><td>36.9%</td><td>9.4</td><td>85.2%</td><td>4.5</td><td>5.8</td></tr></tbody></table></div>

# %% [markdown]
# Looks better! Now, let's try and look at some stats leaders.

# %%
top3PT = display(
    basicOffStats[basicOffStats['_3PA'] > 3][['Name', 'Team', 'GamesPlayed', '_3P_Pct']] ##filter to only look at 3pFGA > 3, only return name, team, games played, 3p%
    .sort_values(by="_3P_Pct", ascending=False) # Sort by 3P% descending
    .head(25) # Onll return Top 25
    [['Name', 'Team', 'GamesPlayed', '_3P_Pct']]
)

top3PT
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Name</th><th>Team</th><th>GamesPlayed</th><th>_3P_Pct</th></tr></thead><tbody><tr><td>Luke Kennard</td><td>LAL</td><td>53</td><td>49.1%</td></tr><tr><td>Sam Merrill</td><td>CLE</td><td>35</td><td>46.6%</td></tr><tr><td>Jaylon Tyson</td><td>CLE</td><td>54</td><td>46.4%</td></tr><tr><td>Jaden McDaniels</td><td>MIN</td><td>57</td><td>45.2%</td></tr><tr><td>Bobby Portis</td><td>MIL</td><td>54</td><td>45.0%</td></tr><tr><td>Ayo Dosunmu</td><td>MIN</td><td>51</td><td>44.0%</td></tr><tr><td>Rui Hachimura</td><td>LAL</td><td>47</td><td>44.0%</td></tr><tr><td>Cam Spencer</td><td>MEM</td><td>54</td><td>43.9%</td></tr><tr><td>Kon Knueppel</td><td>CHA</td><td>58</td><td>43.6%</td></tr><tr><td>Tari Eason</td><td>HOU</td><td>34</td><td>43.6%</td></tr><tr><td>Taurean Prince</td><td>MIL</td><td>8</td><td>42.9%</td></tr><tr><td>John Collins</td><td>LAC</td><td>53</td><td>42.7%</td></tr><tr><td>Isaiah Joe</td><td>OKC</td><td>50</td><td>42.7%</td></tr><tr><td>Jamal Murray</td><td>DEN</td><td>53</td><td>42.3%</td></tr><tr><td>AJ Green</td><td>MIL</td><td>52</td><td>42.3%</td></tr><tr><td>Max Christie</td><td>DAL</td><td>52</td><td>42.3%</td></tr><tr><td>Nikola Jokić</td><td>DEN</td><td>42</td><td>42.1%</td></tr><tr><td>Malik Monk</td><td>SAC</td><td>46</td><td>42.1%</td></tr><tr><td>Ryan Rollins</td><td>MIL</td><td>54</td><td>42.0%</td></tr><tr><td>Collin Gillespie</td><td>PHX</td><td>58</td><td>42.0%</td></tr><tr><td>Miles McBride</td><td>NYK</td><td>35</td><td>42.0%</td></tr><tr><td>Landry Shamet</td><td>NYK</td><td>34</td><td>41.8%</td></tr><tr><td>Peyton Watson</td><td>DEN</td><td>49</td><td>41.7%</td></tr><tr><td>Cameron Johnson</td><td>DEN</td><td>34</td><td>41.7%</td></tr><tr><td>Andrew Wiggins</td><td>MIA</td><td>53</td><td>41.0%</td></tr></tbody></table></div>

# %%
topRPG = basicOffStats[['Name', 'Team', 'GamesPlayed', 'RPG']].sort_values(
        by="RPG", ascending=False).head(10)[['Name', 'Team', 'GamesPlayed', 'RPG']] 

display(topRPG)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Name</th><th>Team</th><th>GamesPlayed</th><th>RPG</th></tr></thead><tbody><tr><td>Nikola Jokić</td><td>DEN</td><td>42</td><td>12.5</td></tr><tr><td>Karl-Anthony Towns</td><td>NYK</td><td>55</td><td>11.7</td></tr><tr><td>Donovan Clingan</td><td>POR</td><td>55</td><td>11.5</td></tr><tr><td>Domantas Sabonis</td><td>SAC</td><td>19</td><td>11.4</td></tr><tr><td>Rudy Gobert</td><td>MIN</td><td>56</td><td>11.4</td></tr><tr><td>Victor Wembanyama</td><td>SAS</td><td>43</td><td>11.3</td></tr><tr><td>Zach Edey</td><td>MEM</td><td>11</td><td>11.1</td></tr><tr><td>Anthony Davis</td><td>DAL</td><td>20</td><td>11.0</td></tr><tr><td>Ivica Zubac</td><td>LAC</td><td>43</td><td>11.0</td></tr><tr><td>Walker Kessler</td><td>UTA</td><td>5</td><td>10.8</td></tr></tbody></table></div>

# %%
topAPG = basicStats[['Name', 'Team', 'GamesPlayed', 'APG']].sort_values(
        by="APG", ascending=False).head(10)[['Name', 'Team', 'GamesPlayed', 'APG']] 

display(topAPG)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Name</th><th>Team</th><th>GamesPlayed</th><th>APG</th></tr></thead><tbody><tr><td>Nikola Jokić</td><td>DEN</td><td>42</td><td>10.5</td></tr><tr><td>Cade Cunningham</td><td>DET</td><td>50</td><td>9.8</td></tr><tr><td>Trae Young</td><td>ATL</td><td>10</td><td>8.9</td></tr><tr><td>Luka Dončić</td><td>LAL</td><td>45</td><td>8.6</td></tr><tr><td>Josh Giddey</td><td>CHI</td><td>38</td><td>8.4</td></tr><tr><td>James Harden</td><td>CLE</td><td>51</td><td>8.1</td></tr><tr><td>Ja Morant</td><td>MEM</td><td>20</td><td>8.0</td></tr><tr><td>Jalen Johnson</td><td>ATL</td><td>54</td><td>7.9</td></tr><tr><td>Kevin Porter Jr.</td><td>MIL</td><td>31</td><td>7.6</td></tr><tr><td>Jamal Murray</td><td>DEN</td><td>53</td><td>7.5</td></tr></tbody></table></div>

# %% [markdown]
# ### Advanced Metrics

# %%
advOffCols = [
    "Name",
    "Pos2",
    "Offensive Archetype",
    "TeamAbbreviation",
    "GamesPlayed",
    "MPG",
    "dpm",
    "o_dpm",
    "d_dpm",
    "PASSING_on-ball-time%",
    "nonPassTOVPct",
    "TS_pct",
    "rTSPct",
    "d_FTA_Per100",
    "SelfORebPct",
    "TeammateMissORebPerc",
    "d_AtRimAssists_Per100"

]

advOffStats = allStats[advOffCols][allStats["MPG"] > 15]  # filter out noise, role players

advOffStats = advOffStats.rename(
    columns={
        "TeamAbbreviation": "Team",
        "Pos2": "Pos",
        "dpm": "DPM",
        "o_dpm": "O_DPM",
        "d_dpm": "D_DPM",
        "PASSING_on-ball-time%": "On_Ball_Time",
        "nonPassTOVPct": "sTOV",
        "rTSPct": "rTS_Pct",
        "d_FTA_Per100": "FTA_Per100",
        "d_AtRimAssists_Per100": "RimAst_Per100"
    }
)

advOffStats = advOffStats.assign(
    MPG = (advOffStats['MPG']).round(1),
    DPM = (advOffStats['DPM']).round(1),
    O_DPM = (advOffStats['O_DPM']).round(1),
    D_DPM = (advOffStats['D_DPM']).round(1),
    On_Ball_Time = (advOffStats['On_Ball_Time']).round(1).astype(str) + '%',
    sTOV = (advOffStats['sTOV']).round(1).astype(str) + '%',
    TS_pct = (advOffStats['TS_pct'] * 100).round(1).astype(str) + '%',
    rTS_Pct = (advOffStats['rTS_Pct']).round(1).astype(str) + '%',
    FTA_Per100 = advOffStats['FTA_Per100'].round(1),   
    SelfORebPct = (advOffStats['SelfORebPct']*100).round(1).astype(str)+'%',
    TeammateMissORebPerc = (advOffStats['TeammateMissORebPerc']*100).round(1).astype(str)+'%',
    RimAst_Per100 = advOffStats['FTA_Per100'].round(1)  
)


display(advOffStats.head(25))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Name</th><th>Pos</th><th>
.2</td></tr><tr><td>Joel Embiid</td><td>C</td><td>Shot Creator</td><td>PHI</td><td>32</td><td>31.2</td><td>3.3</td><td>2.5</td><td>0.8</td><td>17.4%</td><td>8.0%</td><td>60.5%</td><td>2.9%</td><td>13.3</td><td>7.9%</td><td>7.3%</td><td>13.3</td></tr><tr><td>Rudy Gobert</td><td>C</td><td>Roll + Cut Big</td><td>MIN</td><td>56</td><td>31.4</td><td>3.1</td><td>-0.9</td><td>4.0</td><td>6.2%</td><td>11.4%</td><td>67.2%</td><td>9.6%</td><td>6.3</td><td>24.4%</td><td>12.3%</td><td>6.3</td></tr><tr><td>Aaron Gordon</td><td>PF</td><td>Shot Creator</td><td>DEN</td><td>23</td><td>27.9</td><td>3.0</td><td>2.6</td><td>0.4</td><td>21.8%</td><td>2.8%</td><td>63.6%</td><td>6.0%</td><td>8.3</td><td>6.5%</td><td>4.4%</td><td>8.3</td></tr><tr><td>Cade Cunningham</td><td>PG</td><td>Slasher</td><td>DET</td><td>50</td><td>34.9</td><td>3.0</td><td>2.8</td><td>0.2</td><td>42.7%</td><td>6.3%</td><td>55.9%</td><td>-1.8%</td><td>9.4</td><td>3.9%</td><td>2.5%</td><td>9.4</td></tr><tr><td>Jarrett Allen</td><td>C</td><td>Roll + Cut Big</td><td>CLE</td><td>47</td><td>27.4</td><td>3.0</td><td>0.9</td><td>2.1</td><td>7.0%</td><td>7.9%</td><td>65.9%</td><td>8.3%</ ...

# %% [markdown]
# ### Shooting

# %%
shootingCols = [
    "Name",
    "Pos2",
    "Offensive Archetype",
    "TeamAbbreviation",
    "GamesPlayed",
    "MPG",
    "d_AtRimFGA_PerGame",
    "RimFGPerc",
    "d_ShortMidRangeFGA_PerGame",
    "ShortMidFGPerc",
    "d_LongMidRangeFGA_PerGame",
    "LongMidFGPerc",
    "d_FG3A_PerGame",
    "3P_PERC",
    "d_FTA_PerGame",
    "FT_PERC"
]

shootingStats = allStats[shootingCols][(allStats["MPG"] > 15) & (allStats["GamesPlayed"] > 15)]  # filter out noise, role players

shootingStats = shootingStats.rename(
    columns={
        "TeamAbbreviation": "Team",
        "Pos2": "Pos",
        "d_AtRimFGA_PerGame": "Rim_ATT_PerGame",
        "RimFGPerc": "RimFG_Pct",
        "d_ShortMidRangeFGA_PerGame": "ShortMidRangeFGA_PerGame",
        "ShortMidFGPerc": "ShortMidFG_Pct",
        "d_LongMidRangeFGA_PerGame": "LongMidRangeFGA_PerGame",
        "LongMidFGPerc": "LongMidFG_Pct",
        "d_FG3A_PerGame": "_3PA_PerGame",
        "3P_PERC": "_3P_Pct",
        "d_FTA_PerGame": "FTA_PerGame",
        "FT_PERC": "FT_Pct"
    }
)

shootingStats = shootingStats.assign(
    MPG = (shootingStats['MPG']).round(1),
    Rim_ATT_PerGame = (shootingStats['Rim_ATT_PerGame']).round(1),
    RimFG_Pct = (shootingStats['RimFG_Pct']* 100).round(1).astype(str) + '%',
    ShortMidRangeFGA_PerGame = (shootingStats['ShortMidRangeFGA_PerGame']).round(1),
    ShortMidFG_Pct = (shootingStats['ShortMidFG_Pct']* 100).round(1).astype(str) + '%',
2%</td><td>4.2</td><td>78.9%</td></tr><tr><td>Kevin Durant</td><td>SF</td><td>Shot Creator</td><td>HOU</td><td>53</td><td>36.7</td><td>1.5</td><td>72.8%</td><td>6.0</td><td>55.2%</td><td>4.7</td><td>49.8%</td><td>5.8</td><td>40.9%</td><td>6.0</td><td>88.1%</td></tr><tr><td>Joel Embiid</td><td>C</td><td>Shot Creator</td><td>PHI</td><td>32</td><td>31.2</td><td>4.8</td><td>67.5%</td><td>4.5</td><td>47.6%</td><td>4.9</td><td>49.0%</td><td>3.9</td><td>31.7%</td><td>8.5</td><td>85.7%</td></tr><tr><td>Rudy Gobert</td><td>C</td><td>Roll + Cut Big</td><td>MIN</td><td>56</td><td>31.4</td><td>5.4</td><td>76.0%</td><td>0.9</td><td>46.0%</td><td>0.0</td><td>0.0%</td><td>0.1</td><td>0.0%</td><td>4.1</td><td>50.6%</td></tr><tr><td>Aaron Gordon</td><td>PF</td><td>Shot Creator</td><td>DEN</td><td>23</td><td>27.9</td><td>3.7</td><td>76.7%</td><td>2.2</td><td>40.0%</td><td>1.4</td><td>34.4%</td><td>4.6</td><td>40.0%</td><td>4.7</td><td>78.9%</td></tr><tr><td>Cade Cunningham</td><td>PG</td><td>Slasher</td><td>DET</td><td>50</td><td>34.9</td><td>4.9</td><td>62.6%</td><td>6.7</td><td>43.8%</td><td>2.0</td><td>45.5%</td><td>6.0</td><td>33.4%</td><td>6.8</td><td>81.0%</td></tr><tr><td>Jarrett Allen</td><td>C</td><td>Roll + Cut Big</td><td>CLE</td><td>47</td><td>27.4</td><td>5.1</td><td>77.0%</td><td>3.6</td><td>48.0%</td><td>0.3</td><td>53.3%</td><td>0.2</td><td>10.0%</td><td>4.3</td><td>72.9%</td></tr><tr><td>James Harden</td><td>SG</td><td>Shot Creator</td><td>CLE</td><td>51</td><td>35 ...

# %% [markdown]
# ### True Shooting

# %%
trueShootingCols = [
    "Name",
    "Pos2",
    "Offensive Archetype",
    "TeamAbbreviation",
    "GamesPlayed",
    "MPG",
    "d_AtRimFGA_PerGame",
    "RimFGPerc",
    "d_ShortMidRangeFGA_PerGame",
    "ShortMidFGPerc",
    "d_LongMidRangeFGA_PerGame",
    "LongMidFGPerc",
    "d_FG3A_PerGame",
    "3P_PERC",
    "d_FTA_PerGame",
    "FT_PERC"
]

trueShootingStats = allStats[trueShootingCols][(allStats["MPG"] > 15) & (allStats["GamesPlayed"] > 15)]  # filter out noise, role players

trueShootingStats = trueShootingStats.rename(
    columns={
        "TeamAbbreviation": "Team",
        "Pos2": "Pos",
        "d_AtRimFGA_PerGame": "Rim_ATT_PerGame",
        "RimFGPerc": "RimFG_Pct",
        "d_ShortMidRangeFGA_PerGame": "ShortMidRangeFGA_PerGame",
        "ShortMidFGPerc": "ShortMidFG_Pct",
        "d_LongMidRangeFGA_PerGame": "LongMidRangeFGA_PerGame",
        "LongMidFGPerc": "LongMidFG_Pct",
        "d_FG3A_PerGame": "_3PA_PerGame",
        "3P_PERC": "_3P_Pct",
        "d_FTA_PerGame": "FTA_PerGame",
        "FT_PERC": "FT_Pct"
    }
)

trueShootingStats = trueShootingStats.assign(
    MPG = (trueShootingStats['MPG']).round(1),
    Rim_ATT_PerGame = (trueShootingStats['Rim_ATT_PerGame']).round(1),
    RimFG_Pct = (trueShootingStats['RimFG_Pct']* 100).round(1).astype(str) + '%',
    ShortMidRangeFGA_PerGame = (trueShootingStats['ShortMidRangeFGA_PerGame']).round(1),
    ShortMidFG_Pct = (trueShootingStats['ShortMidFG_Pct']* 100).round(1).astype(str) + '%',
    LongMidRangeFGA_PerGame = (trueShootingStats['LongMidRangeFGA_PerGame']).round(1),
    LongMidFG_Pct = (trueShootingStats['LongMidFG_Pct']* 100).round(1).astype(str) + '%',    
    _3PA_PerGame = (trueShootingStats['_3PA_PerGame']).round(1),
    _3P_Pct = (trueShootingStats['_3P_Pct']* 100).round(1).astype(str) + '%',
    FTA_PerGame = (trueShootingStats['FTA_PerGame']).round(1),
    FT_Pct = (trueShootingStats['FT_Pct']* 100).round(1).astype(str) + '%'
)


display(trueShootingStats.head(25))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Name</th><th>Pos</th><th>Offensive Archetype</th><th>Team</th><th>GamesPlayed</th><th>MPG</th><th>Rim_ATT_PerGame</th><th>RimFG_Pct</th><th>ShortMidRangeFGA_PerGame</th><th>ShortMidFG_Pct</th><th>LongMidRangeFGA_PerGame</th><th>LongMidFG_Pct</th><th>_3PA_PerGame</th><th>_3P_Pct</th><th>FTA_PerGame</th><th>FT_Pct</th></tr></thead><tbody><tr><td>Nikola Jokić</td><td>C</td><td>Post Scorer</td><td>DEN</td><td>42</td><td>34.3</td><td>5.0</td><td>75.0%</td><td>6.2</td><td>57.3%</td><td>1.4</td><td>59.3%</td><td>4.6</td><td>42.1%</td><td>8.0</td><td>83.6%</td></tr><tr><td>Shai Gilgeous-Alexander</td><td>PG</td><td>Shot Creator</td><td>OKC</td><td>49</td><td>33.3</td><td>5.0</td><td>70.9%</td><td>6.3</td><td>56.7%</td><td>3.8</td><td>52.4%</td><td>4.6</td><td>39.0%</td><td>9.2</td><td>89.2%</td></tr><tr><td>Kawhi Leonard</td><td>SF</td><td>Shot Creator</td><td>LAC</td><td>44</td><td>32.8</td><td>2.8</td><td>75.2%</td><td>6.7</td><td>51.5%</td><td>3.2</td><td>46.9%</td><td>7.0</td><td>38.1%</td><td>6.5</td><td>90.5%</td></tr><tr><td>Giannis Antetokounmpo</td><td>PF</td><td>Shot Creator</td><td>MIL</td><td>30</td><td>29.2</td><td>10.9</td><td>78.9%</td><td>2.0</td><td>39.3%</td><td>2.0</td><td>27.9%</td><td>1.3</td><td>39.5%</td><td>9.9</td><td>65.8%</td></tr><tr><td>Donovan Mitchell</td><td>PG</td><td>Primary Ball Handler</td><td>CLE</td><td>55</td><td>33.5</td><td>4.5</td><td>66.1%</td><td>4.9</td><td>54.5%</td><td>1.8</td><td>46.5%</td><td>9.4</td><td>36.9%</td><td>6.1</td><td>85.2%</td></tr><tr><td>Victor Wembanyama</td><td>PF</td><td>Versatile Big</td><td>SAS</td><td>43</td><td>29.1</td><td>5.6</td><td>73.3%</td><td>3.4</td><td>41.8%</td><td>2.4</td><td>42.3%</td><td>5.0</td><td>35.8%</td><td>7.1</td><td>81.1%</td></tr><tr><td>Anthony Edwards</td><td>SG</td><td>Shot Creator</td><td>MIN</td><td>49</td><td>35.6</td><td>4.8</td><td>70.3%</td><td>4.3</td><td>46.7%</td><td>3.1</td><td>46.0%</td><td>8.6</td><td>40.0%</td><td>7.2</td><td>78.9%</td></tr><tr><td>Luka Dončić</td><td>SF</td><td
        "td_dts": "dTS",
        "td_dtov": "dTOV",
        "td_dreb": "dREB",
        "d_Steals_PerGame": "STL_PerGame",
        "d_OFFD_PerGame": "OffensiveFoulsDrawn_PerGame",
        "d_Blocks_PerGame": "Blocks_PerGame",
        "d_FTOVs_PerGame": "Forced_TO_PerGame",
        "d_FTOVs_Per100":"Forced_TO_Per100",
        "d_DEFLECTIONS_PerGame": "Deflections_PerGame",
        "d_DEFLECTIONS_Per100": "Deflections_Per100"
    }
)

defensiveStats = defensiveStats.assign(
    MPG = (defensiveStats['MPG']).round(1),
    D_DPM = (defensiveStats['D_DPM']).round(1),
    DRAPM = (defensiveStats['DRAPM']).round(1),
    dTS = (defensiveStats['dTS']).round(1),
    dTOV = (defensiveStats['dTOV']).round(1),
    dREB = (defensiveStats['dREB']),
    STL_PerGame = defensiveStats['STL_PerGame'].round(1),   
    OffensiveFoulsDrawn_PerGame = (defensiveStats['OffensiveFoulsDrawn_PerGame']).round(1),
    Blocks_PerGame = (defensiveStats['Blocks_PerGame']*100).round(1),
    Forced_TO_PerGame = defensiveStats['Forced_TO_PerGame'].round(1),  
    Forced_TO_Per100 = defensiveStats['Forced_TO_Per100'].round(1),  
    Deflections_PerGame = defensiveStats['Deflections_PerGame'].round(1),  
    Deflections_Per100 = defensiveStats['Deflections_Per100'].round(1),      
)


display(defensiveStats.head(25))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Name</th><th>Pos</th><th>Team</th><th>GamesPlayed</th><th>MPG</th><th>D_DPM</th><th>DRAPM</th><th>dTS</th><th>dTOV</th><th>dREB</th><th>STL_PerGame</th><th>OffensiveFoulsDrawn_PerGame</th><th>Blocks_PerGame</th><th>Forced_TO_PerGame</th><th>Forced_TO_Per100</th><th>Deflections_PerGame</th><th>Deflections_Per100</th><th>DefFGReboundPct</th></tr></thead><tbody><tr><td>Nikola Jokić</td><td>C</td><td>DEN</td><td>42</td><td>34.3</td><td>1.4</td><td>1.2</td><td>-0.3</td><td>-0.4</td><td>1.78</td><td>1.4</td><td>0.1</td><td>76.2</td><td>1.5</td><td>2.1</td><td>3.0</td><td>4.1</td><td>0.27</td></tr><tr><td>Shai Gilgeous-Alexander</td><td>PG</td><td>OKC</td><td>49</td><td>33.3</td><td>0.5</td><td>2.0</td><td>1.4</td><td>1.1</td><td>-0.13</td><td>1.3</td><td>0.1</td><td>77.6</td><td>1.4</td><td>2.0</td><td>3.0</td><td>4.3</td><td>0.108</td></tr><tr><td>Kawhi Leonard</td><td>SF</td><td>LAC</td><td>44</td><td>32.8</td><td>1.4</td><td>1.6</td><td>1.0</td><td>0.2</td><td>0.28</td><td>2.0</td><td>0.0</td><td>52.3</td><td>2.0</td><td>3.1</td><td>3.6</td><td>5.6</td><td>0.155</td></tr><tr><td>Giannis Antetokounmpo</td><td>PF</td><td>MIL</td><td>30</td><td>29.2</td><td>1.6</td><td>1.7</td><td>1.8</td><td>-1.0</td><td>1.24</td><td>0.9</td><td>0.0</td><td>73.3</td><td>0.9</td><td>1.5</td><td>1.9</td><td>3.2</td><td>0.22</td></tr><tr><td>Donovan Mitchell</td><td>PG</td><td>CLE</td><td>55</td><td>33.5</td><td>-0.2</td><td>1.1</td><td>0.1</td><td>0.6</td><td>0.11</td><td>1.6</td><td>0.1</td><td>27.3</td><td>1.7</td><td>2.4</td><td>3.0</td><td>4.2</td><td>0.112</td></tr><tr><td>Victor Wembanyama</td><td>PF</td><td>SAS</td><td>43</td><td>29.1</td><td>2.4</td><td>4.4</td><td>3.4</td><td>-0.2</td><td>1.15</td><td
impactStats = allStats[impactCols][(allStats["MPG"] > 15) & (allStats["GamesPlayed"] > 15)]  # filter out noise, role players

impactStats = impactStats.rename(
    columns={
        "TeamAbbreviation": "Team",
        "Pos2": "Pos",
        "o_dpm": "O_DPM",
        "d_dpm": "D_DPM",
        "dpm": "DPM",
        "two_year_orapm": "TwoYear_ORAPM",
        "two_year_drapm": "TwoYear_DRAPM",
        "two_year_rapm": "TwoYear_RAPM", 
        "three_year_orapm": "ThreeYear_ORAPM",
        "three_year_drapm": "ThreeYear_DRAPM",
        "three_year_rapm": "ThreeYear_RAPM",       


    }
)

impactStats = impactStats.assign(
    MPG = (impactStats['MPG']).round(1),
    D_DPM = (impactStats['D_DPM']).round(1),
    O_DPM = (impactStats['O_DPM']).round(1),
    DPM = (impactStats['DPM']).round(1),
    TwoYear_ORAPM = (impactStats['TwoYear_ORAPM']).round(1),
    TwoYear_DRAPM = (impactStats['TwoYear_DRAPM']).round(1),
    TwoYear_RAPM = impactStats['TwoYear_RAPM'].round(1),   
    ThreeYear_ORAPM = (impactStats['ThreeYear_ORAPM']).round(1),
    ThreeYear_DRAPM = (impactStats['ThreeYear_DRAPM']).round(1),
    ThreeYear_RAPM = impactStats['ThreeYear_RAPM'].round(1),     
)


display(impactStats.head(25))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Name</th><th>Pos</th><th>Team</th><th>GamesPlayed</th><th>MPG</th><th>O_DPM</th><th>D_DPM</th><th>DPM</th><th>TwoYear_ORAPM</th><th>TwoYear_DRAPM</th><th>TwoYear_RAPM</th><th>ThreeYear_ORAPM</th><th>ThreeYear_DRAPM</th><th>ThreeYear_RAPM</th></tr></thead><tbody><tr><td>Nikola Jokić</td><td>C</td><td>DEN</td><td>42</td><td>34.3</td><td>5.4</td><td>1.4</td><td>6.8</td><td>6.7</td><td>0.4</td><td>7.1</td><td>7.6</td><td>1.3</td><td>8.8</td></tr><tr><td>Shai Gilgeous-Alexander</td><td>PG</td><td>OKC</td><td>49</td><td>33.3</td><td>5.7</td><td>0.5</td><td>6.2</td><td>6.2</td><td>2.5</td><td>8.7</td><td>6.4</td><td>2.8</td><td>9.3</td></tr><tr><td>Kawhi Leonard</td><td>SF</td><td>LAC</td><td>44</td><td>32.8</td><td>4.6</td><td>1.4</td><td>6.0</td><td>2.7</td><td>0.9</td><td>3.6</td><td>2.8</td><td>1.9</td><td>4.7</td></tr><tr><td>Giannis Antetokounmpo</td><td>PF</td><td>MIL</td><td>30</td><td>29.2</td><td>4.1</td><td>1.6</td><td>5.8</td><td>5.2</td><td>1.2</td><td>6.4</td><td>5.2</td><td>0.6</td><td>5.8</td></tr><tr><td>Donovan Mitchell</td><td>PG</td><td>CLE</td><td>55</td><td>33.5</td><td>5.4</td><td>-0.2</td><td>5.3</td><td>2.8</td><td>0.4</td><td>3.3</td><td>2.7</td><td>1.9</td><td>4.6</td></tr><tr><td>Victor Wembanyama</td><td>PF</td><td>SAS</td><td>43</td><td>29.1</td><td>2.8</td><td>2.4</td><td>5.1</td><td>1.3</td><td>4.4</td><td>5.7</td><td>0.5</td><td>4.9</td><td>5.4</td></tr><tr><td>Anthony Edwards</td><td>SG</td><td>MIN</td><td>49